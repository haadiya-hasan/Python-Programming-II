# %% [markdown]
# #**Assignment - 2 (OOPs Inheritence)**

# %%
#Question - 1 :	Create an ElectricCar class that inherits from the Car class and includes an additional attribute, battery_size.

class Car:
    def __init__(self, model, brand):
        self.model = model
        self.brand = brand

    def display_info(self):
        print(f"Brand: {self.brand}")
        print(f"Model: {self.model}")


class ElectricCar(Car):
    def __init__(self, model, brand, battery_size):
        super().__init__(model, brand)
        self.battery_size = battery_size

    def display_info(self):
        super().display_info()
        print(f"Battery Size: {self.battery_size}")

    def charge(self):
        print(f"{self.model} is charging...")


# Creating object
car1 = ElectricCar("Fortuner EV", "Toyota", "80 kWh")
car1.display_info()
car1.charge()
# Out:
# Brand: Toyota
# Model: Fortuner EV
# Battery Size: 80 kWh
# Fortuner EV is charging...

# %%
#Question - 2 :	Define a Laptop class that inherits from the Computer class and includes an additional attribute, battery_life.

class Computer:
    def __init__(self, brand, processor):
        self.brand = brand
        self.processor = processor

    def specs(self):
        print(f"Brand: {self.brand}, Processor: {self.processor}")


class Laptop(Computer):
    def __init__(self, brand, processor, battery_life):
        super().__init__(brand, processor)
        self.battery_life = battery_life

    def specs(self):
        super().specs()
        print(f"Battery Life: {self.battery_life} hours")


lap1 = Laptop("Dell", "Intel i7", 8)
lap1.specs()
# Out:
# Brand: Dell, Processor: Intel i7
# Battery Life: 8 hours

# %%
#Question - 3 : Create a Smartphone class and add another child class of your choice that inherits from an ElectronicDevice class.
#Include an additional attribute, operating_system.

class smartphone():
    def __init__(self, brand, storage):
        self.brand = brand
        self.storage = storage

class device(smartphone):
    def __init__(self, brand, storage, os):
        super().__init__(brand, storage)
        self.os = os

Phone=device("iPhone","126gb","iOS")
print(Phone.brand, Phone.storage, Phone.os)
# Out:
# iPhone 126gb iOS

# %%
#Question - 4 :	Implement a Musician class and create another child class of your choice that extends an Artist class.
#Include an additional attribute, instrument_played.

class musician():
    def __init__(self, name, age):
        self.name = name
        self.age = age

class artist(musician):
    def __init__(self, name, age, play):
        super().__init__(name, age)
        self.play = play

x= artist("Zakhir Hussain", 73, "Tabla")
print(x.name, x.age, x.play)

x2= artist("A.R Rahman", 58, "Piano")
print(x2.name, x2.age, x2.play)
# Out:
# Zakhir Hussain 73 Tabla
# A.R Rahman 58 Piano

# %%
#Question - 5 :	Define a FictionBook class and add another child class of your choice that inherits from the Book class.
#Include an additional attribute, genre.

class fictionbook:
    def __init__(self,writer,name):
        self.writer=writer
        self.name=name

class book(fictionbook):
    def __init__(self,writer,name,genre):
        super().__init__(writer,name)
        self.genre=genre

s1=book("Percy Jackson and The Lightning Thief","Rick Riordan","Fantasy Fiction")
print(s1.writer, s1.name, s1.genre, sep="\n")
# Out:
# Percy Jackson and The Lightning Thief
# Rick Riordan
# Fantasy Fiction

# %%
#Bonus Question : Create a student class that takes the name & marks of 3 subjects as arguments in the constructor.
#Then create a method to print the average.

class Student:
    def __init__(self, name):
        self.name = name


class Marks(Student):
    def __init__(self, name, m1, m2, m3):
        super().__init__(name)
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def print_average(self):
        average = (self.m1 + self.m2 + self.m3) / 3
        print("Name:", self.name)
        print("Average Marks:", average)


# Creating object
s1 = Marks("Haadiya", 85, 90, 80)
s1.print_average()
# Out:
# Name: Haadiya
# Average Marks: 85.0
